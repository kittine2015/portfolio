# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b>Привет!👋</b>
#
# Меня зовут Огурлиев Анзор, я буду ревьюером твоего проекта. Сразу хочу предложить тебе общаться на "ты", если тебе это неудобно, скажи мне об этом. Нам предстоит пройти с тобой через тернистый и от того интересный путь анализа данных! Можешь не переживать, я всегда помогу тебе, если у тебя возникнут вопросы)
#
# По ходу твоей работы я буду оставлять свои комментарии, по выполненным тобой шагам. Попрошу тебя не удалять их, так мне будет проще отслеживать твой прогресс в случае повторной проверки.
#
# Очень важно вести диалог и обсуждать те пункты, которые у тебя могли не получиться, поэтому, ты можешь оставлять свои комментарии, и мы обязательно во всем разберемся! Самое главное - выделяй свои комментарии удобным для тебя способом (цвет, рамка), но так, чтобы они отчетлитво отличались от моих комментариев. Так мы ни в чем не запутаемся)
#
# Свои комментарии я буду выделять так: <font color='green'>зеленый</font>, <font color='gold'>желтый</font> и <font color='red'>красный</font> цвет, например:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Этот комментарий я буду оставлять, если твое решение оптимально для данного шага.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b> Это не означает, что ты совершил ошибку. Такими комментариями я буду отмечать места, где ты справился с задачей, но её можно решить ещё лучше. Также в таких комментариях я буду оставлять для тебя другие советы.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера V1<a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
# Если решение, которое ты применил на определенном шаге, требует значительных изменений, то я буду оставлять такой комментарий. Тебе нужно будет подумать еще раз как правильным образом решить данный этап. Если ревью содержит такие комментарии, то я не смогу принять проект с первого раза.
# </div>
#
# P.S. В оглавлении комментария ты увидишь `V1` (`V1`, `V2`, `V3`) - это версия моего комментария, которая понадобится нам с тобой, чтобы не запутаться, если потребуется оставить тебе комментарии после первой проверки.

# %% [markdown]
# # Исследование надежности заемщиков

# %% [markdown]
# Во второй части проекта вы выполните шаги 3 и 4. Их вручную проверит ревьюер.
# Чтобы вам не пришлось писать код заново для шагов 1 и 2, мы добавили авторские решения в ячейки с кодом.

# %% [markdown]
# ## Откройте таблицу и изучите общую информацию о данных

# %% [markdown]
# **Задание 1. Импортируйте библиотеку pandas. Считайте данные из csv-файла в датафрейм и сохраните в переменную `data`. Путь к файлу:**
#
# `/datasets/data.csv`

# %%
import pandas as pd

try:
    data = pd.read_csv('/datasets/data.csv')
except:
    data = pd.read_csv('https://code.s3.yandex.net/datasets/data.csv')

# %% [markdown]
# **Задание 2. Выведите первые 20 строчек датафрейма `data` на экран.**

# %%
data.head(20)
# Out:
#     children  days_employed  dob_years            education  education_id  \
# 0          1   -8437.673028         42               высшее             0
# 1          1   -4024.803754         36              среднее             1
# 2          0   -5623.422610         33              Среднее             1
# 3          3   -4124.747207         32              среднее             1
# 4          0  340266.072047         53              среднее             1
# 5          0    -926.185831         27               высшее             0
# 6          0   -2879.202052         43               высшее             0
# 7          0    -152.779569         50              СРЕДНЕЕ             1
# 8          2   -6929.865299         35               ВЫСШЕЕ             0
# 9          0   -2188.756445         41              среднее             1
# 10         2   -4171.483647         36               высшее             0
# 11         0    -792.701887         40              среднее             1
# ...

# %% [markdown]
# **Задание 3. Выведите основную информацию о датафрейме с помощью метода `info()`.**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21525 entries, 0 to 21524
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   children          21525 non-null  int64
#  1   days_employed     19351 non-null  float64
#  2   dob_years         21525 non-null  int64
#  3   education         21525 non-null  object
#  4   education_id      21525 non-null  int64
#  5   family_status     21525 non-null  object
#  6   family_status_id  21525 non-null  int64
#  7   gender            21525 non-null  object
#  8   income_type       21525 non-null  object
#  9   debt              21525 non-null  int64
#  10  total_income      19351 non-null  float64
#  11  purpose           21525 non-null  object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 2.0+ MB

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Удаление пропусков

# %% [markdown]
# **Задание 4. Выведите количество пропущенных значений для каждого столбца. Используйте комбинацию двух методов.**

# %%
data.isna().sum()
# Out:
# children               0
# days_employed       2174
# dob_years              0
# education              0
# education_id           0
# family_status          0
# family_status_id       0
# gender                 0
# income_type            0
# debt                   0
# total_income        2174
# purpose                0
# dtype: int64

# %% [markdown]
# **Задание 5. В двух столбцах есть пропущенные значения. Один из них — `days_employed`. Пропуски в этом столбце вы обработаете на следующем этапе. Другой столбец с пропущенными значениями — `total_income` — хранит данные о доходах. На сумму дохода сильнее всего влияет тип занятости, поэтому заполнить пропуски в этом столбце нужно медианным значением по каждому типу из столбца `income_type`. Например, у человека с типом занятости `сотрудник` пропуск в столбце `total_income` должен быть заполнен медианным доходом среди всех записей с тем же типом.**

# %%
for t in data['income_type'].unique():
    data.loc[(data['income_type'] == t) & (data['total_income'].isna()), 'total_income'] = \
    data.loc[(data['income_type'] == t), 'total_income'].median()

# %% [markdown]
# ### Обработка аномальных значений

# %% [markdown]
# **Задание 6. В данных могут встречаться артефакты (аномалии) — значения, которые не отражают действительность и появились по какой-то ошибке. таким артефактом будет отрицательное количество дней трудового стажа в столбце `days_employed`. Для реальных данных это нормально. Обработайте значения в этом столбце: замените все отрицательные значения положительными с помощью метода `abs()`.**

# %%
data['days_employed'] = data['days_employed'].abs()

# %% [markdown]
# **Задание 7. Для каждого типа занятости выведите медианное значение трудового стажа `days_employed` в днях.**

# %%
data.groupby('income_type')['days_employed'].agg('median')
# Out:
# income_type
# безработный        366413.652744
# в декрете            3296.759962
# госслужащий          2689.368353
# компаньон            1547.382223
# пенсионер          365213.306266
# предприниматель       520.848083
# сотрудник            1574.202821
# студент               578.751554
# Name: days_employed, dtype: float64

# %% [markdown]
# У двух типов (безработные и пенсионеры) получатся аномально большие значения. Исправить такие значения сложно, поэтому оставьте их как есть. Тем более этот столбец не понадобится вам для исследования.

# %% [markdown]
# **Задание 8. Выведите перечень уникальных значений столбца `children`.**

# %%
data['children'].unique()
# Out:
# array([ 1,  0,  3,  2, -1,  4, 20,  5])

# %% [markdown]
# **Задание 9. В столбце `children` есть два аномальных значения. Удалите строки, в которых встречаются такие аномальные значения из датафрейма `data`.**

# %%
data = data[(data['children'] != -1) & (data['children'] != 20)]

# %% [markdown]
# **Задание 10. Ещё раз выведите перечень уникальных значений столбца `children`, чтобы убедиться, что артефакты удалены.**

# %%
data['children'].unique()
# Out:
# array([1, 0, 3, 2, 4, 5])

# %% [markdown]
# ### Удаление пропусков (продолжение)

# %% [markdown]
# **Задание 11. Заполните пропуски в столбце `days_employed` медианными значениями по каждого типа занятости `income_type`.**

# %%
for t in data['income_type'].unique():
    data.loc[(data['income_type'] == t) & (data['days_employed'].isna()), 'days_employed'] = \
    data.loc[(data['income_type'] == t), 'days_employed'].median()

# %% [markdown]
# **Задание 12. Убедитесь, что все пропуски заполнены. Проверьте себя и ещё раз выведите количество пропущенных значений для каждого столбца с помощью двух методов.**

# %%
data.isna().sum()
# Out:
# children            0
# days_employed       0
# dob_years           0
# education           0
# education_id        0
# family_status       0
# family_status_id    0
# gender              0
# income_type         0
# debt                0
# total_income        0
# purpose             0
# dtype: int64

# %% [markdown]
# ### Изменение типов данных

# %% [markdown]
# **Задание 13. Замените вещественный тип данных в столбце `total_income` на целочисленный с помощью метода `astype()`.**

# %%
data['total_income'] = data['total_income'].astype(int)

# %% [markdown]
# ### Обработка дубликатов

# %% [markdown]
# **Задание 14. Обработайте неявные дубликаты в столбце `education`. В этом столбце есть одни и те же значения, но записанные по-разному: с использованием заглавных и строчных букв. Приведите их к нижнему регистру. Проверьте остальные столбцы.**

# %%
data['education'] = data['education'].str.lower()

# %% [markdown]
# **Задание 15. Выведите на экран количество строк-дубликатов в данных. Если такие строки присутствуют, удалите их.**

# %%
data.duplicated().sum()
# Out:
# 71

# %%
data = data.drop_duplicates()

# %% [markdown]
# ### Категоризация данных

# %% [markdown]
# **Задание 16. На основании диапазонов, указанных ниже, создайте в датафрейме `data` столбец `total_income_category` с категориями:**
#
# - 0–30000 — `'E'`;
# - 30001–50000 — `'D'`;
# - 50001–200000 — `'C'`;
# - 200001–1000000 — `'B'`;
# - 1000001 и выше — `'A'`.
#
#
# **Например, кредитополучателю с доходом 25000 нужно назначить категорию `'E'`, а клиенту, получающему 235000, — `'B'`. Используйте собственную функцию с именем `categorize_income()` и метод `apply()`.**

# %%
def categorize_income(income):
    try:
        if 0 <= income <= 30000:
            return 'E'
        elif 30001 <= income <= 50000:
            return 'D'
        elif 50001 <= income <= 200000:
            return 'C'
        elif 200001 <= income <= 1000000:
            return 'B'
        elif income >= 1000001:
            return 'A'
    except:
        pass

# %%
data['total_income_category'] = data['total_income'].apply(categorize_income)

# %% [markdown]
# **Задание 17. Выведите на экран перечень уникальных целей взятия кредита из столбца `purpose`.**

# %%
data['purpose'].unique()
# Out:
# array(['покупка жилья', 'приобретение автомобиля',
#        'дополнительное образование', 'сыграть свадьбу',
#        'операции с жильем', 'образование', 'на проведение свадьбы',
#        'покупка жилья для семьи', 'покупка недвижимости',
#        'покупка коммерческой недвижимости', 'покупка жилой недвижимости',
#        'строительство собственной недвижимости', 'недвижимость',
#        'строительство недвижимости', 'на покупку подержанного автомобиля',
#        'на покупку своего автомобиля',
#        'операции с коммерческой недвижимостью',
#        'строительство жилой недвижимости', 'жилье',
#        'операции со своей недвижимостью', 'автомобили',
#        'заняться образованием', 'сделка с подержанным автомобилем',
#        'получение образования', 'автомобиль', 'свадьба',
#        'получение дополнительного образования', 'покупка своего жилья',
#        'операции с недвижимостью', 'получение высшего образования',
#        'свой автомобиль', 'сделка с автомобилем',
# ...

# %% [markdown]
# **Задание 18. Создайте функцию, которая на основании данных из столбца `purpose` сформирует новый столбец `purpose_category`, в который войдут следующие категории:**
#
# - `'операции с автомобилем'`,
# - `'операции с недвижимостью'`,
# - `'проведение свадьбы'`,
# - `'получение образования'`.
#
# **Например, если в столбце `purpose` находится подстрока `'на покупку автомобиля'`, то в столбце `purpose_category` должна появиться строка `'операции с автомобилем'`.**
#
# **Используйте собственную функцию с именем `categorize_purpose()` и метод `apply()`. Изучите данные в столбце `purpose` и определите, какие подстроки помогут вам правильно определить категорию.**

# %%
def categorize_purpose(row):
    try:
        if 'автом' in row:
            return 'операции с автомобилем'
        elif 'жил' in row or 'недвиж' in row:
            return 'операции с недвижимостью'
        elif 'свад' in row:
            return 'проведение свадьбы'
        elif 'образов' in row:
            return 'получение образования'
    except:
        return 'нет категории'

# %%
data['purpose_category'] = data['purpose'].apply(categorize_purpose)

# %% [markdown]
# ### Шаг 3. Исследуйте данные и ответьте на вопросы

# %% [markdown]
# #### 3.1 Есть ли зависимость между количеством детей и возвратом кредита в срок?

# %%
persantage = data.groupby('children')['debt'].mean()*100
chil_pivot = data.pivot_table(index=['children'], values=['debt'], aggfunc=['count', 'mean', 'sum'], margins=True) 
 
print(chil_pivot)
print()
print(persantage)


 # Ваш код будет здесь. Вы можете создавать новые ячейки. , aggfunc=['count', 'mean', 'sum'], margins=True
    #, values='total_income', ['count','sum', 'mean'] values=['total_income'],columns=
# Out:
#           count      mean   sum
#            debt      debt  debt
# children
# 0         14091  0.075438  1063
# 1          4808  0.092346   444
# 2          2052  0.094542   194
# 3           330  0.081818    27
# 4            41  0.097561     4
# 5             9  0.000000     0
# All       21331  0.081196  1732
#
# children
# 0    7.543822
# 1    9.234609
# 2    9.454191
# 3    8.181818
# 4    9.756098
# 5    0.000000
# Name: debt, dtype: float64

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b> Отлично, что ты решила воспользоваться методом `groupby()` для отображения вероятности просрочки! Стоит вывести более информативную сводную таблицу и добавить некоторые признаки, например, количество клиентов или количество просрочек. Так ты сможешь в полной мере анализировать зависимость и сделаешь корректный вывод.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера V2<a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b> В метод `aggfunc` ты можешь передать список функций, например, `['count', 'sum', 'mean']`, тогда в сводной таблице будет информация о количестве клиентов, количестве просрочек и вероятности просрочки.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера V3<a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
# Ты неправильно построила сводную таблицу. В параметр `values` ты передала доход клиентов, хотя в этом пункте тебе нужно исследовать зависимость просрочки от количества детей. Если ты не знаешь как построить сводную таблицу правильно, то напиши, что именно ты не понимаешь, я помогу. Ты смотрела статью с примера, которую я оставил?
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <h2> Комментарий ученика V3<a class="tocSkip"></h2>
#
#
# <p><b>Здравствуй, Анзор!</b></p>
# Если бы не нехватка времени - не было бы глупых ошибок. Эту статью я читала еще перед первой проверкой :) но, видимо, надо сделать много ошибок. Никак не могла понять, как сделать зависимость по двум параметрам, без третьего.
# <p><b>Огромное спасибо за терпение!</b></p>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V4<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Ты большая молодец! Сейчас ты полностью построила сводную таблицу абсолютно верно.
# </div>

# %%
import seaborn as sns

sns.barplot(x=persantage.index, y=persantage, color='green').set(title='Диаграмма зависимости')
# Out:
# [Text(0.5, 1.0, 'Диаграмма зависимости')]

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Молодец, что визуализировала данные!
# </div>

# %% [markdown]
# **Вывод:** Да, в данном случае есть зависимость. Люди без детей чаще возвращают кредит в положенные сроки. О людях с пятью детьми судить сложно так, как не достаточно данных.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Абсолютно верно! Хорошо, что ты заметила особенность группы клиентов с 5 детьми, для них недостаточно наблюдений, для какого-либо корректного вывода.
# </div>

# %% [markdown]
# #### 3.2 Есть ли зависимость между семейным положением и возвратом кредита в срок?

# %%
persantage_family_status = data.groupby('family_status')['debt'].mean()*100
family_pivot = data.pivot_table(index=['family_status'], values=['debt'], aggfunc=['count', 'mean', 'sum'], margins=True)

print(family_pivot)
print()
print(persantage_family_status)
# Ваш код будет здесь. Вы можете создавать новые ячейки total_income
# Out:
#                        count      mean   sum
#                         debt      debt  debt
# family_status
# Не женат / не замужем   2796  0.097639   273
# в разводе               1189  0.070648    84
# вдовец / вдова           951  0.066246    63
# гражданский брак        4134  0.093130   385
# женат / замужем        12261  0.075606   927
# All                    21331  0.081196  1732
#
# family_status
# Не женат / не замужем    9.763948
# в разводе                7.064760
# вдовец / вдова           6.624606
# гражданский брак         9.313014
# женат / замужем          7.560558
# Name: debt, dtype: float64

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b> Этот комментарий относится ко всем пунктам, которые будут ниже. Стоит также доработать сводную таблицу и вывести другие признаки для групп.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера V2<a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b> Опять же стоит проработать использование методово построения сводных таблиц. Оставлю для тебя ссылку на статью, в которой рассматривают построение сводных таблиц на примерах.
#
# https://dfedorov.spb.ru/pandas/Сводная%20таблица%20в%20pandas.html

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера V3<a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
# Ты неправильно построила сводную таблицу, также как и в предыдущем пункте ты использовала не подходящий признак.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V4<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Здесь тоже все верно все сделала, так держать!
# </div>

# %%
import seaborn as sns
import numpy as np

sns.barplot(x=persantage_family_status.index, y=persantage_family_status, color='blue').set(title='Диаграмма зависимости')
# Out:
# [Text(0.5, 1.0, 'Диаграмма зависимости')]

# %% [markdown]
# **Вывод:** Да, здесь так же есть зависимость. Овдовевшие люди возвращают долг чаще других в положенные сроки. Также на графике выделаются два класса: те, кто чаще оплачивает долг раньше и группа, кто оплачивает с задержками (не женатые люди и люди, состоящие в гражданском браке).

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b> Все верно, какие еще можно сделать выводы, посмотрев на значения вероятности просрочки? Подсказка: на графике группы отчетливо разбиваются на 2 класса.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V2<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Абсолютно верный вывод!
# </div>

# %% [markdown]
# #### 3.3 Есть ли зависимость между уровнем дохода и возвратом кредита в срок?

# %%
total_income_category_persantage = data.groupby('total_income_category')['debt'].mean()*100

total_income_category_pivot = data.pivot_table(index=['total_income_category'], values=['debt'], aggfunc=['count', 'mean', 'sum'])

print(total_income_category_pivot)
print(total_income_category_persantage)
# Ваш код будет здесь. Вы можете создавать новые ячейки.
# Out:
#                        count      mean   sum
#                         debt      debt  debt
# total_income_category
# A                         25  0.080000     2
# B                       5014  0.070602   354
# C                      15921  0.084982  1353
# D                        349  0.060172    21
# E                         22  0.090909     2
# total_income_category
# A    8.000000
# B    7.060231
# C    8.498210
# D    6.017192
# E    9.090909
# Name: debt, dtype: float64

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b> Напоминаю про составление сводной таблицы. Можно воспользоваться методом `pivot_table()`

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера V3<a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
# Здесь в качестве индекса стоило бы передать параметр `total_income_category`, в колонках параметр `debt`. Тебе нужно разобраться с тем, как работает метод `pivot_table()`
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V4<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Все правильно сделала, молодец!
# </div>

# %%
import seaborn as sns
import numpy as np

sns.barplot(x=total_income_category_persantage.index, y=total_income_category_persantage, color='blue').set(title='Диаграмма зависимости')
# Out:
# [Text(0.5, 1.0, 'Диаграмма зависимости')]

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b> Что ты хотела отобразить с помощью данной диаграммы?

# %% [markdown]
# **Вывод:** Прослеживается зависимость задолженнойстей от уровня дохода. Как видно на диаграмме, категоия с доходом от 50 до 200 тысяч имеет хорошую выборку и больше всех имеют задолженностей, категории В и D имеют лучший показатель по выплатам. Судить о категориях А и Е сложно, так как выборка не показательна.
# 0–30000 — 'E';
# 30001–50000 — 'D';
# 50001–200000 — 'C';
# 200001–1000000 — 'B';
# 1000001 и выше — 'A

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера V1<a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
# К сожалению, это неправильный вывод. Ты не проанализировала самое главное, прежде чем делать вывод. Проверь как клиенты распределены между группами, и на основании сделай вывод, можно ли учитывать все категории для дальнейшего анализа?
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V2<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Абсолютно верный вывод, отлично, что ты заметила несбалансированность клиентов между группами.
# </div>

# %% [markdown]
# #### 3.4 Как разные цели кредита влияют на его возврат в срок?

# %%
data.groupby('purpose_category')['debt'].mean()*100 # Ваш код будет здесь. Вы можете создавать новые ячейки.
# Out:
# purpose_category
# операции с автомобилем      9.347978
# операции с недвижимостью    7.255139
# получение образования       9.252758
# проведение свадьбы          7.911803
# Name: debt, dtype: float64

# %% [markdown]
# **Вывод:** Операции, проводимые с недвижимостью имеют наименьший процент задолженности, а кредит на операции с автомобилем - наибольший.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Абсолютно верно!
# </div>

# %% [markdown]
# #### 3.5 Приведите возможные причины появления пропусков в исходных данных.

# %% [markdown]
# *Ответ:* -система могла дать сбой
# -клиент не стал заполнять поле
# -клиент подумал, что заполнение автоматическое

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Полностью согласен с тобой, все эти причины могут возникнуть в реальной жизни. Подумай, какие еще причины могут произойти.
# </div>

# %% [markdown]
# #### 3.6 Объясните, почему заполнить пропуски медианным значением — лучшее решение для количественных переменных.

# %% [markdown]
# *Ответ:* Медиана считает данные более корректо так как, в таблице могут быть сильно выделающиеся значения, что может исказить данные, если считать среднее арифметическое.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Все верно, если в выборке есть выбросы, то они сильно скажутся на значении среднего арифметического, и как следствие, на результатах всего исследования.
# </div>

# %% [markdown]
# ### Шаг 4: общий вывод.

# %% [markdown]
# Напишите ваш общий вывод.
# В ходе исследования были обнаружены следующие закономерности:
# 3.1. Люди без детей чаще возвращают кредит в положенные сроки. А о людях с пятью детьми судить сложно так, как не достаточно данных.
# 3.2. Овдовевшие люди возвращают долг чаще других в положенные сроки.
# 3.3. Прослеживается зависимость задолженнойстей от уровня дохода. Как видно на диаграмме, категоия людей с доходом от 50 до 200 тысяч имеет хорошую выборку и больше всех имеют задолженностей, категории В и D имеют лучший показатель по выплатам. Судить о категориях А и Е сложно, так как выборка не показательна.
# 3.4. Операции, проводимые с недвижимостью имеют наименьший процент задолженности, а кредит на операции с автомобилем - наибольший.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b> В целом хороший вывод. Стоит его доработать с учетом моих комментариев в промежуточных выводах. Также можно разбить вывод на пункты, чтобы визуально можно было разделить основные результаты исследования.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V2<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Прекрасный вывод! Все четко, структурировано и понятно.
# </div>

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# **Общий вывод по проекту**
#
# Спасибо за твой проект! Я уверен, что ты приложила все усилия, чтобы сделать этот проект. Это видно по твоей работе, а сформулированные выводы отражают, насколько успешно ты осваиваешь материал.
#
# **Отмечу отдельные положительные моменты проекта🙂**:
#
# * Ты полностью следовала всем этапам выполнения задания и справилась почти со всем. Хорошая работа!
# * Отдельно выделю некоторые выводы, которые ты смогла сформулировать абсолютно точно!
# * У тебя опрятный и читаемый код. Возможно это звучит банально, однако при работе с чужим кодом это крайне важно)
#
#
# **На что стоит обратить внимание🤓**:
#
# * Важно доработать итоговый вывод.
# * Какие еще причины могут быть причиной пропусков в данных?
# * Какая особенность данных не позволяет сходу дать ответ на вопрос: "Есть ли зависимость между уровнем дохода и возвратом кредита в срок?"
# * Что ты хотела изобразить с помощью круговой диаграммы?
# * Остальные рекомендации ты найдешь в моих комментариях!
#
#
# **Желаю удачи и жду твой проект на повторное ревью!**😉

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# **Общий вывод по проекту**
#
# **На что стоит обратить внимание🤓**:
#
#
# * Нужно поработать над использованием метода `pivot_table()` и правильно построить сводные таблицы.
# * Остальные рекомендации ты найдешь в моих комментариях!
#
#
# **Желаю удачи и жду твой проект на повторное ревью!**😉

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# **Общий вывод по проекту**
#
# **На что стоит обратить внимание🤓**:
#
#
# * Крайне важно поработать над использованием метода `pivot_table()` и правильно построить сводные таблицы. Изучи статью, которую я оставил для тебя ранее, если будут вопросы - не стесняйся и спрашивай, я помогу.
# * Остальные рекомендации ты найдешь в моих комментариях!
#
#
# **Желаю удачи и жду твой проект на повторное ревью!**😉

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# Ты отлично справилась с данной работой! Видно, как ты успешно осваиваешь материал, применяешь полученные знания на практике. Мне было очень приятно проверять твою работу, надеюсь, мои комментарии и советы были для тебя полезными.
#
# **Желаю удачи в последующем обучении и исследованиях!**😉
